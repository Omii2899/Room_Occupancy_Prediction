# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_file = 'data/Occupancy_Estimation.csv'

# %%
df = pd.read_csv(data_file)

# %%
df
# Out:
#              Date      Time  S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  \
# 0      2017/12/22  10:49:41    24.94    24.75    24.56    25.38       121
# 1      2017/12/22  10:50:12    24.94    24.75    24.56    25.44       121
# 2      2017/12/22  10:50:42    25.00    24.75    24.50    25.44       121
# 3      2017/12/22  10:51:13    25.00    24.75    24.56    25.44       121
# 4      2017/12/22  10:51:44    25.00    24.75    24.56    25.44       121
# ...           ...       ...      ...      ...      ...      ...       ...
# 10124  2018/01/11  08:58:07    25.06    25.13    24.69    25.31         6
# 10125  2018/01/11  08:58:37    25.06    25.06    24.69    25.25         6
# 10126  2018/01/11  08:59:08    25.13    25.06    24.69    25.25         6
# 10127  2018/01/11  08:59:39    25.13    25.06    24.69    25.25         6
# 10128  2018/01/11  09:00:09    25.13    25.06    24.69    25.25         6
#
#        S2_Light  S3_Light  S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  \
# ...

# %%
df.shape
# Out:
# (10129, 19)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10129 entries, 0 to 10128
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  10129 non-null  datetime64[ns]
#  1   Time                  10129 non-null  object
#  2   S1_Temp               10129 non-null  float64
#  3   S2_Temp               10129 non-null  float64
#  4   S3_Temp               10129 non-null  float64
#  5   S4_Temp               10129 non-null  float64
#  6   S1_Light              10129 non-null  int64
#  7   S2_Light              10129 non-null  int64
#  8   S3_Light              10129 non-null  int64
#  9   S4_Light              10129 non-null  int64
#  10  S1_Sound              10129 non-null  float64
#  11  S2_Sound              10129 non-null  float64
#  12  S3_Sound              10129 non-null  float64
#  13  S4_Sound              10129 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# Date                    0
# Time                    0
# S1_Temp                 0
# S2_Temp                 0
# S3_Temp                 0
# S4_Temp                 0
# S1_Light                0
# S2_Light                0
# S3_Light                0
# S4_Light                0
# S1_Sound                0
# S2_Sound                0
# S3_Sound                0
# S4_Sound                0
# S5_CO2                  0
# S5_CO2_Slope            0
# S6_PIR                  0
# S7_PIR                  0
# Room_Occupancy_Count    0
# dtype: int64

# %% [markdown]
# As we can see, there are no null values

# %%
df.describe()
# Out:
#                                 Date       S1_Temp       S2_Temp  \
# count                          10129  10129.000000  10129.000000
# mean   2017-12-27 08:26:49.319774720     25.454012     25.546059
# min              2017-12-22 00:00:00     24.940000     24.750000
# 25%              2017-12-23 00:00:00     25.190000     25.190000
# 50%              2017-12-24 00:00:00     25.380000     25.380000
# 75%              2017-12-26 00:00:00     25.630000     25.630000
# max              2018-01-11 00:00:00     26.380000     29.000000
# std                              NaN      0.351351      0.586325
#
#             S3_Temp       S4_Temp      S1_Light     S2_Light      S3_Light  \
# count  10129.000000  10129.000000  10129.000000  10129.00000  10129.000000
# mean      25.056621     25.754125     25.445059     26.01629     34.248494
# min       24.440000     24.940000      0.000000      0.00000      0.000000
# 25%       24.690000     25.440000      0.000000      0.00000      0.000000
# ...

# %%
df['S1_Temp']
# Out:
# 0        24.94
# 1        24.94
# 2        25.00
# 3        25.00
# 4        25.00
#          ...
# 10124    25.06
# 10125    25.06
# 10126    25.13
# 10127    25.13
# 10128    25.13
# Name: S1_Temp, Length: 10129, dtype: float64

# %%
sns.histplot(data=df['Room_Occupancy_Count'])
# Out:
# /Users/omii/anaconda3/envs/Lab_1_7300/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Room_Occupancy_Count', ylabel='Count'>

# %%
df['S1_Temp'].unique()
# Out:
# array([24.94, 25.  , 25.06, 25.13, 25.19, 25.25, 25.31, 25.38, 25.44,
#        25.5 , 25.56, 25.63, 25.69, 25.75, 25.81, 25.94, 26.  , 26.06,
#        26.13, 26.19, 25.88, 26.25, 26.31, 26.38])

# %% [markdown]
# # Correlation of Features & 2-d Plots

# %% [markdown]
# ## Heatmap of correlation of features

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
#        'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound', 'S3_Sound',
#        'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR', 'S7_PIR',
#        'Room_Occupancy_Count'],
#       dtype='object')

# %%
final_df = df.loc[:,['S1_Temp', 'S2_Temp', 'S3_Temp', 'S4_Temp', 'S1_Light',
       'S2_Light', 'S3_Light', 'S4_Light', 'S1_Sound', 'S2_Sound', 'S3_Sound',
       'S4_Sound', 'S5_CO2', 'S5_CO2_Slope', 'S6_PIR', 'S7_PIR',
       'Room_Occupancy_Count']]

# %%
final_array = np.array(final_df)

# %%
final_df
# Out:
#        S1_Temp  S2_Temp  S3_Temp  S4_Temp  S1_Light  S2_Light  S3_Light  \
# 0        24.94    24.75    24.56    25.38       121        34        53
# 1        24.94    24.75    24.56    25.44       121        33        53
# 2        25.00    24.75    24.50    25.44       121        34        53
# 3        25.00    24.75    24.56    25.44       121        34        53
# 4        25.00    24.75    24.56    25.44       121        34        54
# ...        ...      ...      ...      ...       ...       ...       ...
# 10124    25.06    25.13    24.69    25.31         6         7        33
# 10125    25.06    25.06    24.69    25.25         6         7        34
# 10126    25.13    25.06    24.69    25.25         6         7        34
# 10127    25.13    25.06    24.69    25.25         6         7        34
# 10128    25.13    25.06    24.69    25.25         6         7        34
#
#        S4_Light  S1_Sound  S2_Sound  S3_Sound  S4_Sound  S5_CO2  S5_CO2_Slope  \
# ...

# %%
final_array
# Out:
# 38.983233040385365

# %%
np.mean(final_array, axis = 0)
# Out:
# array([ 2.54540122e+01,  2.55460588e+01,  2.50566206e+01,  2.57541248e+01,
#         2.54450587e+01,  2.60162899e+01,  3.42484944e+01,  1.32202587e+01,
#         1.68177510e-01,  1.20066147e-01,  1.58119262e-01,  1.03840458e-01,
#         4.60860401e+02, -4.83000068e-03,  9.01372297e-02,  7.95735018e-02,
#         3.98558594e-01])

# %%
final_df.corr()
# Out:
#                        S1_Temp   S2_Temp   S3_Temp   S4_Temp  S1_Light  \
# S1_Temp               1.000000  0.799707  0.948839  0.855279  0.680743
# S2_Temp               0.799707  1.000000  0.765525  0.696581  0.639773
# S3_Temp               0.948839  0.765525  1.000000  0.885186  0.594311
# S4_Temp               0.855279  0.696581  0.885186  1.000000  0.581482
# S1_Light              0.680743  0.639773  0.594311  0.581482  1.000000
# S2_Light              0.548735  0.645987  0.500054  0.456350  0.842090
# S3_Light              0.645163  0.607349  0.642601  0.588459  0.816438
# S4_Light              0.212217  0.370897  0.301419  0.386871  0.510853
# S1_Sound              0.436099  0.438274  0.375183  0.355111  0.601166
# S2_Sound              0.391137  0.409545  0.344026  0.312594  0.534274
# S3_Sound              0.438769  0.427133  0.398177  0.340808  0.494080
# S4_Sound              0.355826  0.378724  0.326182  0.294939  0.441712
# ...

# %%
sns.heatmap(final_df.corr(), annot=True, cmap = 'gray')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
sns.heatmap(final_df.corr(), cmap = 'gray', linewidth = 0.5)
# Out:
# <Axes: >
